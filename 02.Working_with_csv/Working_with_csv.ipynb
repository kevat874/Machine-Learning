# %% [markdown]
# 1.Importing Pandas

# %%
import pandas as pd

# %% [markdown]
# 2.opening a Local csv file

# %%
df=pd.read_csv('Fortune 500.csv')

# %%
df
# Out:
#      Rank        Company Name Number of Employees  Previous Rank   Revenues  \
# 0       1             Walmart           23,00,000            1.0  $4,85,873
# 1       2  Berkshire Hathaway            3,67,700            4.0  $2,23,604
# 2       3               Apple            1,16,000            3.0  $2,15,639
# 3       4         Exxon Mobil              72,700            2.0  $2,05,004
# 4       5            McKesson              68,000            5.0  $1,92,487
# ..    ...                 ...                 ...            ...        ...
# 495   496       Michaels Cos.              31,000          517.0     $5,197
# 496   497       Toll Brothers               4,200          576.0     $5,170
# 497   498               Yahoo               8,500          513.0     $5,169
# 498   499       Vistra Energy               4,431            NaN     $5,164
# 499   500      ABM Industries            1,10,000          485.0     $5,145
#
# ...

# %% [markdown]
# Openning a csv file from url

# %%
import request
from io import StringIO

url= "https://raw.githubusercontent.com/cs09/2014_data/master/countries.csv"
headers = {"User-Agent": "Mozilla/5.0(Macintosh;Intel Mac OS X 10.14; rv:66.0) Gecko/20100101 Firefox/66.0"}
req = request.get(url,headers = headers)
data = StringIO(req.text)

pd.read_csv(data)

# %% [markdown]
# Sep parameter

# %%
pd.read_csv('Fortune 500.csv',sep='/t',names=['sno','name','release_year','rating','votes']) #converted csv file into tsv but "tsv" is converted in "csv" then use'/t'
# Out:
# /var/folders/ry/wgj587lj7y5fgymw0jbl6lgm0000gn/T/ipykernel_18195/2696268509.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   pd.read_csv('Fortune 500.csv',sep='/t',names=['sno','name','release_year','rating','votes']) #converted csv file into tsv but "tsv" is converted in "csv" then use'/t'
#                                                    sno  name  release_year  \
# 0    Rank,Company Name,Number of Employees,Previous...   NaN           NaN
# 1    1,Walmart,"23,00,000",1,"$4,85,873",0.8%,"$13,...   NaN           NaN
# 2    2,Berkshire Hathaway,"3,67,700",4,"$2,23,604",...   NaN           NaN
# 3    3,Apple,"1,16,000",3,"$2,15,639",-7.7%,"$45,68...   NaN           NaN
# 4    4,Exxon Mobil,"72,700",2,"$2,05,004",-16.7%,"$...   NaN           NaN
# ...

# %% [markdown]
# 5.Index_col Parameter

# %%
pd.read_csv('Fortune 500.csv',index_col='Rank')
# Out:
#             Company Name Number of Employees  Previous Rank   Revenues  \
# Rank
# 1                Walmart           23,00,000            1.0  $4,85,873
# 2     Berkshire Hathaway            3,67,700            4.0  $2,23,604
# 3                  Apple            1,16,000            3.0  $2,15,639
# 4            Exxon Mobil              72,700            2.0  $2,05,004
# 5               McKesson              68,000            5.0  $1,92,487
# ...                  ...                 ...            ...        ...
# 496        Michaels Cos.              31,000          517.0     $5,197
# 497        Toll Brothers               4,200          576.0     $5,170
# 498                Yahoo               8,500          513.0     $5,169
# 499        Vistra Energy               4,431            NaN     $5,164
# 500       ABM Industries            1,10,000          485.0     $5,145
#
#      Revenue Change    Profits Profit Change     Assets Market Value
# Rank
# ...

# %% [markdown]
# 6. Header Parameter

# %%
pd.read_csv('Fortune 500.csv',header=1)
# Out:
#        1             Walmart 23,00,000    1.1  $4,85,873    0.8%  $13,643.0  \
# 0      2  Berkshire Hathaway  3,67,700    4.0  $2,23,604    6.1%  $24,074.0
# 1      3               Apple  1,16,000    3.0  $2,15,639   -7.7%  $45,687.0
# 2      4         Exxon Mobil    72,700    2.0  $2,05,004  -16.7%   $7,840.0
# 3      5            McKesson    68,000    5.0  $1,92,487    6.2%   $2,258.0
# 4      6  UnitedHealth Group  2,30,000    6.0  $1,84,840   17.7%   $7,017.0
# ..   ...                 ...       ...    ...        ...     ...        ...
# 494  496       Michaels Cos.    31,000  517.0     $5,197    5.8%     $378.2
# 495  497       Toll Brothers     4,200  576.0     $5,170   23.9%     $382.1
# 496  498               Yahoo     8,500  513.0     $5,169    4.0%    -$214.3
# 497  499       Vistra Energy     4,431    NaN     $5,164       -          -
# 498  500      ABM Industries  1,10,000  485.0     $5,145   -2.8%      $57.2
#
#       -7.2%  $1,98,825  $2,18,619
# ...

# %% [markdown]
# 7.use_cols Parameter

# %%
pd.read_csv('Fortune 500.csv',usecols=['Company Name','Revenues','Profits'])
# Out:
#            Company Name   Revenues    Profits
# 0               Walmart  $4,85,873  $13,643.0
# 1    Berkshire Hathaway  $2,23,604  $24,074.0
# 2                 Apple  $2,15,639  $45,687.0
# 3           Exxon Mobil  $2,05,004   $7,840.0
# 4              McKesson  $1,92,487   $2,258.0
# ..                  ...        ...        ...
# 495       Michaels Cos.     $5,197     $378.2
# 496       Toll Brothers     $5,170     $382.1
# 497               Yahoo     $5,169    -$214.3
# 498       Vistra Energy     $5,164          -
# 499      ABM Industries     $5,145      $57.2
#
# [500 rows x 3 columns]

# %% [markdown]
# 8.Squeeze parameter

# %%
pd.read_csv('Fortune 500.csv',usecols=['Company Name'],squeeze=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 pd.read_csv('Fortune 500.csv',usecols=['Company Name'],squeeze=True)
#
# TypeError: read_csv() got an unexpected keyword argument 'squeeze'

# %% [markdown]
# 9.skiprows/nrows Parameter

# %%
pd.read_csv('Fortune 500.csv',skiprows=[0,5])
# Out:
#        1             Walmart 23,00,000    1.1  $4,85,873    0.8%  $13,643.0  \
# 0      2  Berkshire Hathaway  3,67,700    4.0  $2,23,604    6.1%  $24,074.0
# 1      3               Apple  1,16,000    3.0  $2,15,639   -7.7%  $45,687.0
# 2      4         Exxon Mobil    72,700    2.0  $2,05,004  -16.7%   $7,840.0
# 3      6  UnitedHealth Group  2,30,000    6.0  $1,84,840   17.7%   $7,017.0
# 4      7          CVS Health  2,04,000    7.0  $1,77,526   15.8%   $5,317.0
# ..   ...                 ...       ...    ...        ...     ...        ...
# 493  496       Michaels Cos.    31,000  517.0     $5,197    5.8%     $378.2
# 494  497       Toll Brothers     4,200  576.0     $5,170   23.9%     $382.1
# 495  498               Yahoo     8,500  513.0     $5,169    4.0%    -$214.3
# 496  499       Vistra Energy     4,431    NaN     $5,164       -          -
# 497  500      ABM Industries  1,10,000  485.0     $5,145   -2.8%      $57.2
#
#       -7.2%  $1,98,825  $2,18,619
# ...

# %%
pd.read_csv('Fortune 500.csv',nrows=100)
# Out:
#     Rank            Company Name Number of Employees  Previous Rank  \
# 0      1                 Walmart           23,00,000            1.0
# 1      2      Berkshire Hathaway            3,67,700            4.0
# 2      3                   Apple            1,16,000            3.0
# 3      4             Exxon Mobil              72,700            2.0
# 4      5                McKesson              68,000            5.0
# ..   ...                     ...                 ...            ...
# 95    96  Charter Communications              91,500          292.0
# 96    97     Northwestern Mutual               5,646          100.0
# 97    98                Facebook              17,048          157.0
# 98    99          Travelers Cos.              30,900          105.0
# 99   100   Capital One Financial              47,300          112.0
#
#      Revenues Revenue Change    Profits Profit Change     Assets Market Value
# ...

# %% [markdown]
# 10.Encoding parameter

# %%
pd.read_csv('zomato.csv',encoding='latin-1')
# Out:
#       Restaurant ID           Restaurant Name  Country Code              City  \
# 0           6317637          Le Petit Souffle           162       Makati City
# 1           6304287          Izakaya Kikufuji           162       Makati City
# 2           6300002    Heat - Edsa Shangri-La           162  Mandaluyong City
# 3           6318506                      Ooma           162  Mandaluyong City
# 4           6314302               Sambo Kojin           162  Mandaluyong City
# ...             ...                       ...           ...               ...
# 9546        5915730              NamlÛ± Gurme           208         ÛÁstanbul
# 9547        5908749             Ceviz AÛôacÛ±           208         ÛÁstanbul
# 9548        5915807                     Huqqa           208         ÛÁstanbul
# 9549        5916112              Aôôk Kahve           208         ÛÁstanbul
# 9550        5927402  Walter's Coffee Roastery           208         ÛÁstanbul
#
# ...

# %% [markdown]
# 11. Skip Bad Line

# %%
pd.read_csv('zomato.csv',error_bad_line=False)

# %% [markdown]
# 12.dtype parameter

# %%
pd.read_csv('Fortune 500.csv',dtype={'Rank':float})
# Out:
#       Rank        Company Name Number of Employees  Previous Rank   Revenues  \
# 0      1.0             Walmart           23,00,000            1.0  $4,85,873
# 1      2.0  Berkshire Hathaway            3,67,700            4.0  $2,23,604
# 2      3.0               Apple            1,16,000            3.0  $2,15,639
# 3      4.0         Exxon Mobil              72,700            2.0  $2,05,004
# 4      5.0            McKesson              68,000            5.0  $1,92,487
# ..     ...                 ...                 ...            ...        ...
# 495  496.0       Michaels Cos.              31,000          517.0     $5,197
# 496  497.0       Toll Brothers               4,200          576.0     $5,170
# 497  498.0               Yahoo               8,500          513.0     $5,169
# 498  499.0       Vistra Energy               4,431            NaN     $5,164
# 499  500.0      ABM Industries            1,10,000          485.0     $5,145
#
# ...

# %% [markdown]
# 13.Handling dates

# %%
pd.read_csv('matches.csv',parse_dates=['date']).info
# Out:
# <bound method DataFrame.info of       id  season       city       date                        team1  \
# 0      1    2017  Hyderabad 2017-04-05          Sunrisers Hyderabad
# 1      2    2017       Pune 2017-04-06               Mumbai Indians
# 2      3    2017     Rajkot 2017-04-07                Gujarat Lions
# 3      4    2017     Indore 2017-04-08       Rising Pune Supergiant
# 4      5    2017  Bangalore 2017-04-08  Royal Challengers Bangalore
# ..   ...     ...        ...        ...                          ...
# 631  632    2016     Raipur 2016-05-22             Delhi Daredevils
# 632  633    2016  Bangalore 2016-05-24                Gujarat Lions
# 633  634    2016      Delhi 2016-05-25          Sunrisers Hyderabad
# 634  635    2016      Delhi 2016-05-27                Gujarat Lions
# 635  636    2016  Bangalore 2016-05-29          Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# ...

# %% [markdown]
# 14.Converters

# %%
def rename(name):
    if name == "Royal Challengers Bangalore":
        return "RCB"
    else :
        return name

# %%
rename("Royal Challengers Bangalore")
# Out:
# 'RCB'

# %%
pd.read_csv('matches.csv',converters={'team2':rename})
# Out:
#       id  season       city        date                        team1  \
# 0      1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1      2    2017       Pune  2017-04-06               Mumbai Indians
# 2      3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3      4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4      5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
# ..   ...     ...        ...         ...                          ...
# 631  632    2016     Raipur  2016-05-22             Delhi Daredevils
# 632  633    2016  Bangalore  2016-05-24                Gujarat Lions
# 633  634    2016      Delhi  2016-05-25          Sunrisers Hyderabad
# 634  635    2016      Delhi  2016-05-27                Gujarat Lions
# 635  636    2016  Bangalore  2016-05-29          Sunrisers Hyderabad
#
#                       team2                  toss_winner toss_decision  \
# ...

# %% [markdown]
# 15.na_values Parameter

# %%
pd.read_csv('matches.csv',na_values=['umpire1'])
# Out:
#       id  season       city        date                        team1  \
# 0      1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1      2    2017       Pune  2017-04-06               Mumbai Indians
# 2      3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3      4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4      5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
# ..   ...     ...        ...         ...                          ...
# 631  632    2016     Raipur  2016-05-22             Delhi Daredevils
# 632  633    2016  Bangalore  2016-05-24                Gujarat Lions
# 633  634    2016      Delhi  2016-05-25          Sunrisers Hyderabad
# 634  635    2016      Delhi  2016-05-27                Gujarat Lions
# 635  636    2016  Bangalore  2016-05-29          Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# ...

# %% [markdown]
# 16.Loading a Huge dataset in chunks

# %%
dfs = pd.read_csv('matches.csv',chunksize=100)

# %%
for chunks in dfs:
    print(chunks.shape)
# Out:
# (100, 18)
# (100, 18)
# (100, 18)
# (100, 18)
# (100, 18)
# (36, 18)
